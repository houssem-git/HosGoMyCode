# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
#importing Data---
df=pd.read_csv("C:/Users/Houssem Maalej/Downloads/titanic-passengers.csv",sep=";")
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
#preprocessing------
#----Cleaning-------
df['Cabin'].fillna("AAA",inplace=True)
df.isnull().sum().sum()
df['Age'].fillna(df['Age'].median(),inplace=True)
df.isnull().sum().sum()
df['Embarked'].fillna("Yes",inplace=True)
df.isnull().sum().sum()
#------
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    AAA        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    AAA        S
# 3  female  29.0      0      4      349909  21.0750    AAA        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
import seaborn as sns 
#--------distribution du Sex
sns.countplot(x='Sex',data=df)
plt.xticks(rotation=-45)
# Out:
# (array([0, 1]), <a list of 2 Text xticklabel objects>)

# %%
sns.boxplot(df['Age'])

# %%
#Correlation using Seaborn the Age of Survivals----------------------
g=sns.FacetGrid(df,col="Sex")  
g.map(plt.hist,'Age',bins=20)

# %%
#Correlation using Seaborn the Age of Survivals----------------------
g=sns.FacetGrid(df,col="Survived")  
g.map(plt.hist,'Sex',bins=20)

# %%
#Correlating multiple numerical and categorical features
grid=sns.FacetGrid(df,row='Sex',col="Survived",size=2.2,aspect=1.6)
grid.map(sns.barplot,'Sex','Age',alpha=.5,ci=None)
grid.add_legend()
# Out:
# C:\Users\Houssem Maalej\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Houssem Maalej\anaconda3\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map( df )
#this function return a table showing correlation coefficients between variables. 
#Each cell in the table shows the correlation between two variables. 
#it's used to summarize data.

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['Survived']=encoder.fit_transform(df['Survived'])#we need to convert from categorical to numeric values!
df[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
#df.drop(['Name'], axis=1) #we deleted the column 'Name'

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  28.0      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch      Ticket     Fare  Cabin Embarked
# 0        0      248740  13.0000    AAA        S
# 1        0      348123   7.6500  F G73        S
# 2        0      350050   7.8542    AAA        S
# 3        4      349909  21.0750    AAA        S
# 4        0  F.C. 12750  52.0000    B71        S
# ..     ...         ...      ...    ...      ...
# 886      0      237736  30.0708    AAA        C
# 887      0        2669   7.2292    AAA        C
# 888      0      315084   8.6625    AAA        S
# 889      0      349215   7.8958    AAA        S
# 890      0      250655  26.0000    AAA        S
#
# [891 rows x 12 columns]

# %%
#extracting Title----------
extractedTitle=list()
for names in df['Name']:
    extractedTitle.append(names.replace('.',',').split(','))
    
extractedTitleFinal=list()    

for i in extractedTitle:
    extractedTitleFinal.append(i[1])
    
extractedTitleFinal
# Out:
# [' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Dr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Major',
#  ' Mrs',
#  ' Don',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Master',
#  ' Dr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Miss',
#  ' Miss',
#  ' Master',
#  ' Miss',
#  ' Mr',
#  ' Rev',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Miss',
#  ' Mrs',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Col',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Miss',
#  ' Master',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Dr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mrs',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Master',
#  ' Mlle',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Master',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Dr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mrs',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mrs',
#  ' Mrs',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Master',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Lady',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Master',
#  ' Mrs',
#  ' Mrs',
#  ' Master',
#  ' Mrs',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Dr',
#  ' Dr',
#  ' Mrs',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Master',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mlle',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Master',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Jonkheer',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Master',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Master',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mme',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mrs',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Sir',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Capt',
#  ' Mrs',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Mrs',
#  ' Major',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Rev',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Rev',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Dr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Mrs',
#  ' Col',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Rev',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Rev',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' the Countess',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Master',
#  ' Master',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Miss',
#  ' Ms',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Rev',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss']

# %%
#----------------------
Title_Dictionary = {'Title':{

                    'Capt':       'Officer',

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer", 

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty", 

                  "the Countess" : "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"}

                    }

# %%
# using insert function to create a new column 
df.insert(3, "Title", extractedTitleFinal, True)

# Print the DataFrame after addition 
# of new column 
df.replace(Title_Dictionary,inplace=True)

df
# Out:
#      PassengerId  Survived  Pclass  Title  \
# 0            343         0       2     Mr
# 1             76         0       3     Mr
# 2            641         0       3     Mr
# 3            568         0       3    Mrs
# 4            672         0       1     Mr
# ..           ...       ...     ...    ...
# 886           10         1       2    Mrs
# 887           61         0       3     Mr
# 888          535         0       3   Miss
# 889          102         0       3     Mr
# 890          428         1       2   Miss
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  28.0      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch      Ticket     Fare  Cabin Embarked
# 0        0      248740  13.0000    AAA        S
# 1        0      348123   7.6500  F G73        S
# 2        0      350050   7.8542    AAA        S
# 3        4      349909  21.0750    AAA        S
# 4        0  F.C. 12750  52.0000    B71        S
# ..     ...         ...      ...    ...      ...
# 886      0      237736  30.0708    AAA        C
# 887      0        2669   7.2292    AAA        C
# 888      0      315084   8.6625    AAA        S
# 889      0      349215   7.8958    AAA        S
# 890      0      250655  26.0000    AAA        S
#
# [891 rows x 13 columns]

# %%
plt.plot(df['Title'],df['Age'])
plt.show()
